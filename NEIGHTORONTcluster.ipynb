# %% [markdown]
# ## This notebook contains the assignment for capstone project Neighbouhoods in Toronto.
# ### SCRAPING THE WIKIPEDIA PAGE

# %%
# install geopy & folium
# !conda install -c conda-forge geopy --yes
# !conda install -c conda-forge folium=0.5.0 --yes
# import Libraries that we need
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2019.07=py37_0
#   - defaults/win-64::numba==0.44.1=py37hf9181ef_0
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hp\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     ca-certificates-2019.9.11  |       hecc5488_0         181 KB  conda-forge
#     certifi-2019.9.11          |           py37_0         155 KB
#     openssl-1.1.1c             |       hfa6e2cd_0         4.7 MB  conda-forge
#     tbb-2019.9                 |       he980bc4_0         161 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2019.03-py37_0
#   tbb                conda-forge/win-64::tbb-2019.9-he980bc4_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.5.15-0 --> conda-forge::ca-certificates-2019.9.11-hecc5488_0
#   certifi                                  2019.6.16-py37_0 --> 2019.9.11-py37_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl              pkgs/main::openssl-1.1.1c-he774522_1 --> conda-forge::openssl-1.1.1c-hfa6e2cd_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.07-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2019 | 181 KB    |            |   0%
# ca-certificates-2019 | 181 KB    | 8          |   9%
# ca-certificates-2019 | 181 KB    | #7         |  18%
# ca-certificates-2019 | 181 KB    | #######9   |  80%
# ca-certificates-2019 | 181 KB    | ########8  |  89%
# ca-certificates-2019 | 181 KB    | #########7 |  97%
# ca-certificates-2019 | 181 KB    | ########## | 100%
#
# certifi-2019.9.11    | 155 KB    |            |   0%
# certifi-2019.9.11    | 155 KB    | #          |  10%
# certifi-2019.9.11    | 155 KB    | ####1      |  41%
# certifi-2019.9.11    | 155 KB    | #####1     |  52%
# certifi-2019.9.11    | 155 KB    | #########3 |  93%
# certifi-2019.9.11    | 155 KB    | ########## | 100%
#
# tbb-2019.9           | 161 KB    |            |   0%
# tbb-2019.9           | 161 KB    | 9          |  10%
# tbb-2019.9           | 161 KB    | ####9      |  50%
# tbb-2019.9           | 161 KB    | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# openssl-1.1.1c       | 4.7 MB    |            |   0%
# openssl-1.1.1c       | 4.7 MB    |            |   0%
# openssl-1.1.1c       | 4.7 MB    | 2          |   2%
# openssl-1.1.1c       | 4.7 MB    | 2          |   3%
# openssl-1.1.1c       | 4.7 MB    | 8          |   9%
# openssl-1.1.1c       | 4.7 MB    | #1         |  11%
# openssl-1.1.1c       | 4.7 MB    | #3         |  14%
# openssl-1.1.1c       | 4.7 MB    | ##         |  20%
# openssl-1.1.1c       | 4.7 MB    | ##3        |  23%
# openssl-1.1.1c       | 4.7 MB    | ##5        |  25%
# openssl-1.1.1c       | 4.7 MB    | ###2       |  32%
# openssl-1.1.1c       | 4.7 MB    | ###5       |  36%
# openssl-1.1.1c       | 4.7 MB    | ####       |  41%
# openssl-1.1.1c       | 4.7 MB    | ####3      |  43%
# openssl-1.1.1c       | 4.7 MB    | ####5      |  45%
# openssl-1.1.1c       | 4.7 MB    | ####7      |  48%
# openssl-1.1.1c       | 4.7 MB    | ####9      |  50%
# openssl-1.1.1c       | 4.7 MB    | #####      |  51%
# openssl-1.1.1c       | 4.7 MB    | #####2     |  52%
# openssl-1.1.1c       | 4.7 MB    | #####3     |  54%
# openssl-1.1.1c       | 4.7 MB    | #####4     |  55%
# openssl-1.1.1c       | 4.7 MB    | #####6     |  56%
# openssl-1.1.1c       | 4.7 MB    | #####7     |  57%
# openssl-1.1.1c       | 4.7 MB    | #####8     |  58%
# openssl-1.1.1c       | 4.7 MB    | #####9     |  59%
# openssl-1.1.1c       | 4.7 MB    | ######     |  61%
# openssl-1.1.1c       | 4.7 MB    | ######1    |  62%
# openssl-1.1.1c       | 4.7 MB    | ######3    |  63%
# openssl-1.1.1c       | 4.7 MB    | ######4    |  65%
# openssl-1.1.1c       | 4.7 MB    | ######5    |  66%
# openssl-1.1.1c       | 4.7 MB    | ######6    |  67%
# openssl-1.1.1c       | 4.7 MB    | ######7    |  68%
# openssl-1.1.1c       | 4.7 MB    | ######8    |  69%
# openssl-1.1.1c       | 4.7 MB    | ######9    |  70%
# openssl-1.1.1c       | 4.7 MB    | #######    |  71%
# openssl-1.1.1c       | 4.7 MB    | #######1   |  72%
# openssl-1.1.1c       | 4.7 MB    | #######2   |  73%
# openssl-1.1.1c       | 4.7 MB    | #######3   |  73%
# openssl-1.1.1c       | 4.7 MB    | #######4   |  74%
# openssl-1.1.1c       | 4.7 MB    | #######4   |  75%
# openssl-1.1.1c       | 4.7 MB    | #######5   |  76%
# openssl-1.1.1c       | 4.7 MB    | #######6   |  76%
# openssl-1.1.1c       | 4.7 MB    | #######7   |  77%
# openssl-1.1.1c       | 4.7 MB    | #######7   |  78%
# openssl-1.1.1c       | 4.7 MB    | #######9   |  79%
# openssl-1.1.1c       | 4.7 MB    | ########   |  80%
# openssl-1.1.1c       | 4.7 MB    | ########1  |  81%
# openssl-1.1.1c       | 4.7 MB    | ########2  |  82%
# openssl-1.1.1c       | 4.7 MB    | ########2  |  83%
# openssl-1.1.1c       | 4.7 MB    | ########3  |  83%
# openssl-1.1.1c       | 4.7 MB    | ########4  |  84%
# openssl-1.1.1c       | 4.7 MB    | ########5  |  85%
# openssl-1.1.1c       | 4.7 MB    | ########5  |  86%
# openssl-1.1.1c       | 4.7 MB    | ########6  |  86%
# openssl-1.1.1c       | 4.7 MB    | ########7  |  88%
# openssl-1.1.1c       | 4.7 MB    | ########8  |  88%
# openssl-1.1.1c       | 4.7 MB    | ########9  |  89%
# openssl-1.1.1c       | 4.7 MB    | #########  |  90%
# openssl-1.1.1c       | 4.7 MB    | #########  |  91%
# openssl-1.1.1c       | 4.7 MB    | #########1 |  91%
# openssl-1.1.1c       | 4.7 MB    | #########2 |  92%
# openssl-1.1.1c       | 4.7 MB    | #########2 |  93%
# openssl-1.1.1c       | 4.7 MB    | #########4 |  94%
# openssl-1.1.1c       | 4.7 MB    | #########5 |  95%
# openssl-1.1.1c       | 4.7 MB    | #########6 |  97%
# openssl-1.1.1c       | 4.7 MB    | #########7 |  98%
# openssl-1.1.1c       | 4.7 MB    | #########8 |  98%
# openssl-1.1.1c       | 4.7 MB    | #########9 |  99%
# openssl-1.1.1c       | 4.7 MB    | ########## | 100%
#
# anaconda-custom      | 3 KB      |            |   0%
# anaconda-custom      | 3 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hp\Anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-3.2.0               |           py37_0         749 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     certifi-2019.6.16          |           py37_1         149 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         996 KB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/win-64::altair-3.2.0-py37_0
#   branca             conda-forge/noarch::branca-0.3.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi               pkgs/main::certifi-2019.9.11-py37_0 --> conda-forge::certifi-2019.6.16-py37_1
#
#
#
# Downloading and Extracting Packages
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ###5       |  35%
# folium-0.5.0         | 45 KB     | ########## | 100%
#
# altair-3.2.0         | 749 KB    |            |   0%
# altair-3.2.0         | 749 KB    | 2          |   2%
# altair-3.2.0         | 749 KB    | 8          |   9%
# altair-3.2.0         | 749 KB    | #7         |  17%
# altair-3.2.0         | 749 KB    | ##1        |  21%
# altair-3.2.0         | 749 KB    | ###2       |  32%
# altair-3.2.0         | 749 KB    | ###8       |  38%
# altair-3.2.0         | 749 KB    | ####7      |  47%
# altair-3.2.0         | 749 KB    | #####3     |  53%
# altair-3.2.0         | 749 KB    | #####9     |  60%
# altair-3.2.0         | 749 KB    | ######6    |  66%
# altair-3.2.0         | 749 KB    | #######2   |  73%
# altair-3.2.0         | 749 KB    | #######9   |  79%
# altair-3.2.0         | 749 KB    | ########9  |  90%
# altair-3.2.0         | 749 KB    | #########6 |  96%
# altair-3.2.0         | 749 KB    | ########## | 100%
#
# branca-0.3.1         | 25 KB     |            |   0%
# branca-0.3.1         | 25 KB     | ######3    |  63%
# branca-0.3.1         | 25 KB     | ########## | 100%
#
# certifi-2019.6.16    | 149 KB    |            |   0%
# certifi-2019.6.16    | 149 KB    | #          |  11%
# certifi-2019.6.16    | 149 KB    | #####3     |  54%
# certifi-2019.6.16    | 149 KB    | ########6  |  86%
# certifi-2019.6.16    | 149 KB    | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | #####7     |  58%
# vincent-0.4.4        | 28 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
page_soup=BeautifulSoup(page.content,'html.parser')

# %%
table = page_soup.find('tbody')
rows = table.select('tr')
row = [r.get_text() for r in rows]

# %% [markdown]
# # Data Wrangling

# %%
df = pd.DataFrame(row)
df = df[0].str.split('\n', expand=True)
df = df.rename(columns=df.iloc[0])
df = df.drop(df.index[0])
df.head()
# Out:
#     Postcode           Borough     Neighbourhood
# 1        M1A      Not assigned      Not assigned
# 2        M2A      Not assigned      Not assigned
# 3        M3A        North York         Parkwoods
# 4        M4A        North York  Victoria Village
# 5        M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ## Ignore cells with a borough that is Not assigned

# %%
df=df[df.Borough !="Not assigned"]
df.head()
# Out:
#     Postcode           Borough     Neighbourhood
# 3        M3A        North York         Parkwoods
# 4        M4A        North York  Victoria Village
# 5        M5A  Downtown Toronto      Harbourfront
# 6        M5A  Downtown Toronto       Regent Park
# 7        M6A        North York  Lawrence Heights

# %% [markdown]
# # Combine neighborhoods which have the same postcode

# %%
df = df.groupby(['Postcode', 'Borough'], sort = False).agg(','.join)
df.reset_index(inplace = True)
df.head()
# Out:
#   Postcode           Borough                    Neighbourhood
# 0      M3A        North York                        Parkwoods
# 1      M4A        North York                 Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront,Regent Park
# 3      M6A        North York  Lawrence Heights,Lawrence Manor
# 4      M7A      Queen's Park                     Not assigned

# %% [markdown]
# ## If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.

# %%
df = df.replace("Not assigned", "Queen's Park")
df.head()
# Out:
#   Postcode           Borough                    Neighbourhood
# 0      M3A        North York                        Parkwoods
# 1      M4A        North York                 Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront,Regent Park
# 3      M6A        North York  Lawrence Heights,Lawrence Manor
# 4      M7A      Queen's Park                     Queen's Park

# %% [markdown]
# ## .shape method to print the number of rows of your dataframe

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Read Geo CSV file

# %%
url = "http://cocl.us/Geospatial_data"
df1 = pd.read_csv(url)
df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## Rename first column name

# %%
df1.rename(columns={'Postal Code': 'Postcode'}, inplace=True)
df1.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %% [markdown]
# ## Merging two frames on Postcode

# %%
df = pd.merge(df, df1, on='Postcode')
df.head()
# Out:
#   Postcode           Borough                    Neighbourhood   Latitude  \
# 0      M3A        North York                        Parkwoods  43.753259
# 1      M4A        North York                 Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront,Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights,Lawrence Manor  43.718518
# 4      M7A      Queen's Park                     Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# ## Show how many Borough & Neighbourhood in the dataframe

# %%
print('The dataframe has {} Borough and {} Neighbourhood.'.format(
        len(df['Borough'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 11 Borough and 103 Neighbourhood.

# %% [markdown]
# ## Create a new dataframe for only boroughs that contain the word Toronto

# %%
Toronto=df[df['Borough'].str.contains('Toronto')]
Toronto
# Out:
#     Postcode           Borough  \
# 2        M5A  Downtown Toronto
# 9        M5B  Downtown Toronto
# 15       M5C  Downtown Toronto
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 30       M5H  Downtown Toronto
# 31       M6H      West Toronto
# 36       M5J  Downtown Toronto
# 37       M6J      West Toronto
# 41       M4K      East Toronto
# 42       M5K  Downtown Toronto
# 43       M6K      West Toronto
# 47       M4L      East Toronto
# 48       M5L  Downtown Toronto
# 54       M4M      East Toronto
# 61       M4N   Central Toronto
# 62       M5N   Central Toronto
# 67       M4P   Central Toronto
# 68       M5P   Central Toronto
# 69       M6P      West Toronto
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
#
#                                          Neighbourhood   Latitude  Longitude
# 2                             Harbourfront,Regent Park  43.654260 -79.360636
# 9                              Ryerson,Garden District  43.657162 -79.378937
# 15                                      St. James Town  43.651494 -79.375418
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 30                              Adelaide,King,Richmond  43.650571 -79.384568
# 31                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 36     Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 37                             Little Portugal,Trinity  43.647927 -79.419750
# 41                         The Danforth West,Riverdale  43.679557 -79.352188
# 42             Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 43          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 47                       The Beaches West,India Bazaar  43.668999 -79.315572
# 48                       Commerce Court,Victoria Hotel  43.648198 -79.379817
# 54                                     Studio District  43.659526 -79.340923
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 67                                    Davisville North  43.712751 -79.390197
# 68                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 69                        High Park,The Junction South  43.661608 -79.464763
# 73                                  North Toronto West  43.715383 -79.405678
# 74                   The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 75                               Parkdale,Roncesvalles  43.648960 -79.456325
# 79                                          Davisville  43.704324 -79.388790
# 80                       Harbord,University of Toronto  43.662696 -79.400049
# 81                                   Runnymede,Swansea  43.651571 -79.484450
# 83                          Moore Park,Summerhill East  43.689574 -79.383160
# 84             Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 86   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 87   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 96                          Cabbagetown,St. James Town  43.667967 -79.367675
# 97               First Canadian Place,Underground city  43.648429 -79.382280
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %% [markdown]
# ## Generate map to visualize neighborhoods and how they cluster together

# %%
address = 'Toronto'
geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

Toronto_map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(Toronto['Latitude'], Toronto['Longitude'], 
                                           Toronto['Borough'], Toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Toronto_map)  
    
Toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
